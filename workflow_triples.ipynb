# %% [markdown]
# # Downloading workflows and triple creation
#
# I will download the available workflows from the [website](https://quangis.github.io/wfgen/) and include them in this document. I do it in a single directory. Then I need to create files with triples based on that. One file will contain single input triples, while the other will contain multiple input triples.
#
# ---
#
# ## 1. Donwloading workflows

# %%
# libraries for scraping the workflows
import requests
from bs4 import BeautifulSoup as bs 
import os
import re


#libraries for triple generation
from rdflib import Graph, RDF, RDFS, Namespace  
import codecs
import itertools
import pandas as pd
#import os


#library for saving file 
import pickle

# %%
# indicating the directory where workflows will be saved (saparate folder)
dir_workflows = "C:/Users/wlibe/OneDrive/Pulpit/Thesis/final_code/workflows" 

# defining the webside we want to scrape
url = "https://quangis.github.io/wfgen/"

# geting the response form the server url
response = requests.get(url)

# creating a BeaufifulSoup object 
soup = bs(response.content, 'html.parser')
 
# Finding all hyperlinks, which is indicated by "a" in HTML
links = soup.find_all('a')

# since the files are not numbered in order, we are indicating that the name 
#should have the same number as the file on the url  
name = re.compile(r'solution(\d+)\.ttl')

# %%
#creating the loop to donwload the workflows 

i = 0
 
# from all links check if there is a .ttl file and then donwload it 
for link in links:
    
    # this makes sure that we only download files if the href exists 
    href = link.get('href')
    
    # making sure that files are not empty and then it ends with ".ttl"
    if href and href.endswith(".ttl"):
        pattern = name.search(href)
        if pattern: 
            # extracting the numeric part of the URL file name e.g. the 100 from "solution100.ttl"
            solution_number = int(pattern.group(1)) 
            print("Downloading file: ", solution_number)
 
        # get response object for link
        f_response = requests.get(url + href)
        
        # check if the status is "ok" = 200
        if f_response.status_code == 200:
 
            # Write content in ttl file in specific directory
            file_path = os.path.join(dir_workflows, f"solution{solution_number}.ttl")
            with open(file_path, 'wb') as file:
                file.write(f_response.content)
            print("solution ", solution_number, " downloaded")
        else:
            print("Failes to download", href)
            
# adding the message when all files are downloaded  
print("All ttl files downloaded")
# Out:
# Downloading file:  100
# solution  100  downloaded
# Downloading file:  101
# solution  101  downloaded
# Downloading file:  102
# solution  102  downloaded
# Downloading file:  103
# solution  103  downloaded
# Downloading file:  104
# solution  104  downloaded
# Downloading file:  105
# solution  105  downloaded
# Downloading file:  106
# solution  106  downloaded
# Downloading file:  107
# solution  107  downloaded
# Downloading file:  108
# solution  108  downloaded
# Downloading file:  109
# solution  109  downloaded
# Downloading file:  10
# solution  10  downloaded
# Downloading file:  110
# solution  110  downloaded
# Downloading file:  111
# solution  111  downloaded
# Downloading file:  112
# solution  112  downloaded
# Downloading file:  113
# solution  113  downloaded
# Downloading file:  114
# solution  114  downloaded
# Downloading file:  115
# solution  115  downloaded
# Downloading file:  116
# solution  116  downloaded
# Downloading file:  117
# solution  117  downloaded
# Downloading file:  118
# solution  118  downloaded
# Downloading file:  119
# solution  119  downloaded
# Downloading file:  11
# solution  11  downloaded
# Downloading file:  120
# solution  120  downloaded
# Downloading file:  121
# solution  121  downloaded
# Downloading file:  122
# solution  122  downloaded
# Downloading file:  123
# solution  123  downloaded
# Downloading file:  124
# solution  124  downloaded
# Downloading file:  125
# solution  125  downloaded
# Downloading file:  126
# solution  126  downloaded
# Downloading file:  127
# solution  127  downloaded
# Downloading file:  128
# solution  128  downloaded
# Downloading file:  129
# solution  129  downloaded
# Downloading file:  12
# solution  12  downloaded
# Downloading file:  130
# solution  130  downloaded
# Downloading file:  131
# solution  131  downloaded
# Downloading file:  132
# solution  132  downloaded
# Downloading file:  133
# solution  133  downloaded
# Downloading file:  134
# solution  134  downloaded
# Downloading file:  135
# solution  135  downloaded
# Downloading file:  136
# solution  136  downloaded
# Downloading file:  137
# solution  137  downloaded
# Downloading file:  138
# solution  138  downloaded
# Downloading file:  139
# solution  139  downloaded
# Downloading file:  13
# solution  13  downloaded
# Downloading file:  140
# solution  140  downloaded
# Downloading file:  141
# solution  141  downloaded
# Downloading file:  142
# solution  142  downloaded
# Downloading file:  143
# solution  143  downloaded
# Downloading file:  144
# solution  144  downloaded
# Downloading file:  145
# solution  145  downloaded
# Downloading file:  146
# solution  146  downloaded
# Downloading file:  147
# solution  147  downloaded
# Downloading file:  148
# solution  148  downloaded
# Downloading file:  149
# solution  149  downloaded
# Downloading file:  14
# solution  14  downloaded
# Downloading file:  150
# solution  150  downloaded
# Downloading file:  151
# solution  151  downloaded
# Downloading file:  152
# solution  152  downloaded
# Downloading file:  153
# solution  153  downloaded
# Downloading file:  154
# solution  154  downloaded
# Downloading file:  155
# solution  155  downloaded
# Downloading file:  156
# solution  156  downloaded
# Downloading file:  157
# solution  157  downloaded
# Downloading file:  158
# solution  158  downloaded
# Downloading file:  159
# solution  159  downloaded
# Downloading file:  15
# solution  15  downloaded
# Downloading file:  160
# solution  160  downloaded
# Downloading file:  161
# solution  161  downloaded
# Downloading file:  162
# solution  162  downloaded
# Downloading file:  163
# solution  163  downloaded
# Downloading file:  164
# solution  164  downloaded
# Downloading file:  165
# solution  165  downloaded
# Downloading file:  166
# solution  166  downloaded
# Downloading file:  167
# solution  167  downloaded
# Downloading file:  168
# solution  168  downloaded
# Downloading file:  16
# solution  16  downloaded
# Downloading file:  17
# solution  17  downloaded
# Downloading file:  18
# solution  18  downloaded
# Downloading file:  19
# solution  19  downloaded
# Downloading file:  1
# solution  1  downloaded
# Downloading file:  20
# solution  20  downloaded
# Downloading file:  21
# solution  21  downloaded
# Downloading file:  22
# solution  22  downloaded
# Downloading file:  23
# solution  23  downloaded
# Downloading file:  24
# solution  24  downloaded
# Downloading file:  25
# solution  25  downloaded
# Downloading file:  26
# solution  26  downloaded
# Downloading file:  27
# solution  27  downloaded
# Downloading file:  28
# solution  28  downloaded
# Downloading file:  29
# solution  29  downloaded
# Downloading file:  2
# solution  2  downloaded
# Downloading file:  30
# solution  30  downloaded
# Downloading file:  31
# solution  31  downloaded
# Downloading file:  32
# solution  32  downloaded
# Downloading file:  33
# solution  33  downloaded
# Downloading file:  34
# solution  34  downloaded
# Downloading file:  35
# solution  35  downloaded
# Downloading file:  36
# solution  36  downloaded
# Downloading file:  37
# solution  37  downloaded
# Downloading file:  38
# solution  38  downloaded
# Downloading file:  39
# solution  39  downloaded
# Downloading file:  3
# solution  3  downloaded
# Downloading file:  40
# solution  40  downloaded
# Downloading file:  41
# solution  41  downloaded
# Downloading file:  42
# solution  42  downloaded
# Downloading file:  43
# solution  43  downloaded
# Downloading file:  44
# solution  44  downloaded
# Downloading file:  45
# solution  45  downloaded
# Downloading file:  46
# solution  46  downloaded
# Downloading file:  47
# solution  47  downloaded
# Downloading file:  48
# solution  48  downloaded
# Downloading file:  49
# solution  49  downloaded
# Downloading file:  4
# solution  4  downloaded
# Downloading file:  50
# solution  50  downloaded
# Downloading file:  51
# solution  51  downloaded
# Downloading file:  52
# solution  52  downloaded
# Downloading file:  53
# solution  53  downloaded
# Downloading file:  54
# solution  54  downloaded
# Downloading file:  55
# solution  55  downloaded
# Downloading file:  56
# solution  56  downloaded
# Downloading file:  57
# solution  57  downloaded
# Downloading file:  58
# solution  58  downloaded
# Downloading file:  59
# solution  59  downloaded
# Downloading file:  5
# solution  5  downloaded
# Downloading file:  60
# solution  60  downloaded
# Downloading file:  61
# solution  61  downloaded
# Downloading file:  62
# solution  62  downloaded
# Downloading file:  63
# solution  63  downloaded
# Downloading file:  64
# solution  64  downloaded
# Downloading file:  65
# solution  65  downloaded
# Downloading file:  66
# solution  66  downloaded
# Downloading file:  67
# solution  67  downloaded
# Downloading file:  68
# solution  68  downloaded
# Downloading file:  69
# solution  69  downloaded
# Downloading file:  6
# solution  6  downloaded
# Downloading file:  70
# solution  70  downloaded
# Downloading file:  71
# solution  71  downloaded
# Downloading file:  72
# solution  72  downloaded
# Downloading file:  73
# solution  73  downloaded
# Downloading file:  74
# solution  74  downloaded
# Downloading file:  75
# solution  75  downloaded
# Downloading file:  76
# solution  76  downloaded
# Downloading file:  77
# solution  77  downloaded
# Downloading file:  78
# solution  78  downloaded
# Downloading file:  79
# solution  79  downloaded
# Downloading file:  7
# solution  7  downloaded
# Downloading file:  80
# solution  80  downloaded
# Downloading file:  81
# solution  81  downloaded
# Downloading file:  82
# solution  82  downloaded
# Downloading file:  83
# solution  83  downloaded
# Downloading file:  84
# solution  84  downloaded
# Downloading file:  85
# solution  85  downloaded
# Downloading file:  86
# solution  86  downloaded
# Downloading file:  87
# solution  87  downloaded
# Downloading file:  88
# solution  88  downloaded
# Downloading file:  89
# solution  89  downloaded
# Downloading file:  8
# solution  8  downloaded
# Downloading file:  90
# solution  90  downloaded
# Downloading file:  91
# solution  91  downloaded
# Downloading file:  92
# solution  92  downloaded
# Downloading file:  93
# solution  93  downloaded
# Downloading file:  94
# solution  94  downloaded
# Downloading file:  95
# solution  95  downloaded
# Downloading file:  96
# solution  96  downloaded
# Downloading file:  97
# solution  97  downloaded
# Downloading file:  98
# solution  98  downloaded
# Downloading file:  99
# solution  99  downloaded
# Downloading file:  9
# solution  9  downloaded
# All ttl files downloaded

# %% [markdown]
# ---
#
# ## 2. Triple generation
#
# Workflows we are working with can have multiple inputs, for example:
#
# ```<https://example.com/#solution1> a ns1:Workflow ;
#     ns1:edge [ ns1:applicationOf <https://quangis.github.io/tool/abstract#IntersectDissolveField2Object> ;
#             ns1:input1 _:N8b188f868bb14f86b6950485f8506bd2 ;
#             ns1:input2 _:Ncb1ae296722548d0b16ea9ad84370570 ;
#             ns1:output _:N381929c2bc3145ba933d79736ba97aff ],
# ```

# %% [markdown]
# We can clearly see that there are 'input_1' and 'input_2' for the same output. What is also important to indicate is that we take *inputs* as a **head** of the triple, *tool* (for example 'IntersectDissolveField2Object') as a **relation**, and lastly as a **tail** we indicate the *output*.
#
# That is why this section is divided into two subsections. In the first one (2.1), we create triples with only one input. Based on the example above, tripple would look like this:
#
# >*(input_1, IntersectDissolveField2Object, output)*
# >*(input_2, IntersectDissolveField2Object, output)*
#
# Then the second section will contain triples with multiple inputs, so they will look like this:
#
# >*([input_1, input_2], IntersectDissolveField2Object, output)*
#
#
# ### 2.1 Single input triples

# %%
# Create an RDF graph
graph = Graph()

# Define the prefix that are in the workflows 
prefixes = {
    "ns1": Namespace("http://geographicknowledge.de/vocab/Workflow.rdf#"),
    "rdfs": Namespace("http://www.w3.org/2000/01/rdf-schema#"),
    "cc": Namespace("http://geographicknowledge.de/vocab/CoreConceptData.rdf#"),
}

# Bind the prefixes in the graph
for prefix, namespace in prefixes.items():
    graph.bind(prefix, namespace)
    
# changing working directory to the one where the workflows are saved   
directory_files = "C:/Users/wlibe/OneDrive/Pulpit/Thesis/final_code/workflows"
os.chdir(directory_files)

# iterate over files in that directory
for files in os.listdir(directory_files):
    file = graph.parse(files, format="turtle")

# %%
# Iempty list to store the triples 
triples_single = []

# Iterate over the triples in the graph
for subject in graph.subjects(RDF.type, prefixes["ns1"].Workflow):
    
    # Extract the data, tool, and data triples
    for edge_obj in graph.objects(subject, prefixes["ns1"].edge):
        tool_name = None
        inputs = []
        outputs = []
        for rel_predicate, rel_obj in graph.predicate_objects(edge_obj):
            if rel_predicate == prefixes["ns1"].applicationOf:
                # Extract the tool name
                tool_name = str(rel_obj).split("#")[-1]
            elif rel_predicate == prefixes["ns1"].input1 or rel_predicate == prefixes["ns1"].input2:
                inputs.append(rel_obj)
            elif rel_predicate == prefixes["ns1"].output:
                outputs.append(rel_obj)

        # Create separate triples for each input-output relationship
        for input_obj in inputs:
            for output_obj in outputs:
                # Get the rdfs:label for input_obj and output_obj
                input_label = graph.value(input_obj, RDFS.label)
                output_label = graph.value(output_obj, RDFS.label)
                if input_label and output_label:
                    triples_single.append((input_label, tool_name, output_label))
                else:
                    triples_single.append((input_obj, tool_name, output_obj))

# %%
# printing the triples 
for triple in triples_single:
    print(triple)
# Out:
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, VectorTessellationA, PlainNominalA'), 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainIntervalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainOrdinalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainIntervalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, IRA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainRatioA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, CountA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, VectorTessellationA, PlainNominalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, VectorTessellationA, PlainOrdinalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('FieldQ, PointA, PlainIntervalA'), 'KrigingInterval', rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'), 'Slope', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'), 'Slope', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('FieldQ, PointA, PlainRatioA'), 'KrigingInterval', rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, PlainVectorRegionA, PlainNominalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'), 'Slope', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, IRA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainOrdinalA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, IRA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainRatioA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainIntervalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainRatioA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainOrdinalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainIntervalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, IRA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainRatioA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PointA, CountA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, VectorTessellationA, PlainNominalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, VectorTessellationA, PlainOrdinalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'), 'Slope', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('FieldQ, PointA, PlainIntervalA'), 'IDWInterval', rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# (rdflib.term.Literal('FieldQ, PointA, PlainRatioA'), 'IDWInterval', rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'), 'Slope', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, PlainVectorRegionA, PlainNominalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'), 'Slope', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), 'SelectLayerByAttributeTessObjects2', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainOrdinalA'), 'SelectLayerByAttributeTessObjects2', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'), 'SelectLayerByAttributeTessObjects2', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SelectLayerByAttributeTessObjects2', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, IRA'), 'SelectLayerByAttributeTessObjects2', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainRatioA'), 'SelectLayerByAttributeTessObjects2', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), 'SelectLayerByObjectTessObjects', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, BooleanA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, BooleanA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainIntervalA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'SelectLayerByLocationPlainRegionObjects', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationPlainRegionObjects', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainOrdinalA'), 'SelectLayerByLocationPlainRegionObjects', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationPlainRegionObjects', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainIntervalA'), 'SelectLayerByLocationPlainRegionObjects', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationPlainRegionObjects', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectNeighborhoodsByLocationDistPointObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'SelectNeighborhoodsByLocationDistPointObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, IRA'), 'JoinObjectRatios', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'JoinObjectRatios', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainRatioA'), 'JoinObjectRatios', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'JoinObjectRatios', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SelectNeighborhoodsByLocationDistPointObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, CountA'), 'SelectNeighborhoodsByLocationDistPointObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainIntervalA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, VectorTessellationA, PlainOrdinalA'), 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SpatialJoinSumTessCount', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessCount', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainOrdinalA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainIntervalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# ...
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), 'ZonalStatisticsSize', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSize', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinMeanTessCount', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), 'SpatialJoinMeanTessCount', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainIntervalA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainOrdinalA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainIntervalA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PointA, IRA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainRatioA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PointA, CountA'), 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, VectorTessellationA, PlainNominalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, VectorTessellationA, PlainOrdinalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('FieldQ, PointA, PlainIntervalA'), 'KrigingInterval', rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'), 'Slope', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, PointA, PlainRatioA'), 'KrigingInterval', rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'), 'Slope', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('FieldQ, PlainVectorRegionA, PlainNominalA'), 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainOrdinalA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA'), 'Slope', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainOrdinalA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, OrdinalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, IRA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainRatioA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), 'convert2PointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), 'makePointObjects', rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'))
# (rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), 'addObjectCapacity', rdflib.term.Literal('ObjectQ, PointA, ERA'))
# (rdflib.term.Literal('ObjectQ, PointA, ERA'), 'KernelDensity', rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'))

# %%
# changing working directory to floder where I wantfiles to be saved   
directory_triples = "C:/Users/wlibe/OneDrive/Pulpit/Thesis/final_code/triples"
os.chdir(directory_triples)

#saving the single input triple into pickle file 
with open('triples_single_input.pkl', 'wb') as file:
    pickle.dump(triples_single, file)

# %%
# opening the picke file 
with open('triples_single_input.pkl', 'rb') as file:
    triples_single = pickle.load(file)
    
# saving the triple list into a data frame 
df_single = pd.DataFrame(triples_single, columns = ["head", "relation", "tail"])

#saving the triplets into pickle file 
with open('triples_single_df.pkl', 'wb') as file:
    pickle.dump(df_single, file)

# %% [markdown]
# ### 2.2 Multiple input triples

# %%
# Initialize an empty list to store triples
triples_multiple = []

# Iterate over the triples in the graph
for subject in graph.subjects(RDF.type, prefixes["ns1"].Workflow):
    
    # Extract the data, tool, and data triples
    for edge_obj in graph.objects(subject, prefixes["ns1"].edge):
        tool_name = None
        inputs = []
        outputs = []
        for rel_predicate, rel_obj in graph.predicate_objects(edge_obj):
            if rel_predicate == prefixes["ns1"].applicationOf:
                # Extract the tool name
                tool_name = str(rel_obj).split("#")[-1]
            elif rel_predicate == prefixes["ns1"].input1 or rel_predicate == prefixes["ns1"].input2:
                inputs.append(rel_obj)
            elif rel_predicate == prefixes["ns1"].output:
                outputs.append(rel_obj)

        # create triples with multiple inputs 
        for input_set in itertools.combinations(inputs, 2):
            input_list = []  # Ilist to store multiple inputs
            for input_obj in input_set:
                input_label = graph.value(input_obj, RDFS.label)
                if input_label:
                    input_list.append(input_label)
                else:
                    input_list.append(input_obj)
            for output_obj in outputs:
                output_label = graph.value(output_obj, RDFS.label)
                if output_label:
                    triples_multiple.append((input_list, tool_name, output_label))
                else:
                    triples_multiple.append((input_list, tool_name, output_obj))

# %%
# priniting multiple input triples 
for triple in triples_multiple:
    print(triple)
# Out:
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('FieldQ, VectorTessellationA, PlainNominalA')], 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainIntervalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, VectorTessellationA, PlainNominalA')], 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, VectorTessellationA, PlainOrdinalA')], 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, PlainVectorRegionA, PlainNominalA')], 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, IRA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainIntervalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainRatioA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('FieldQ, VectorTessellationA, PlainNominalA')], 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('FieldQ, VectorTessellationA, PlainOrdinalA')], 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('FieldQ, RasterA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'ZonalStatisticsMeanRatio', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('FieldQ, PlainVectorRegionA, PlainNominalA')], 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, BooleanA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainIntervalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationPlainRegionObjects', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, PointA, PlainOrdinalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationPlainRegionObjects', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PointA, PlainIntervalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationPlainRegionObjects', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PointA, ERA')], 'SelectNeighborhoodsByLocationDistPointObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, PointA, IRA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'JoinObjectRatios', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SelectLayerByLocationTessObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PointA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'JoinObjectRatios', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'ClipObject2Object', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, PointA, CountA')], 'SelectNeighborhoodsByLocationDistPointObject', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainIntervalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('FieldQ, VectorTessellationA, PlainOrdinalA')], 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessCount', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PointA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PointA, PlainOrdinalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SelectLayerByLocationTessObjects', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainRatioA'), rdflib.term.Literal('ObjectQ, PointA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PointA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainRatioA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PointA, IRA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinMeanTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainRatioA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainRatioA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PointA, PlainRatioA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinMeanTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainRatioA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), rdflib.term.Literal('ObjectQ, PointA, CountA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('FieldQ, VectorTessellationA, PlainNominalA')], 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA')], 'ZonalStatisticsMeanInterval', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('FieldQ, VectorTessellationA, PlainOrdinalA')], 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA')], 'ZonalStatisticsSize', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA')], 'ZonalStatisticsSize', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('FieldQ, PlainVectorRegionA, PlainNominalA')], 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'), rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA')], 'ZonalStatisticsSize', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsMeanInterval', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA')], 'SpatialJoinMeanTessCount', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainOrdinalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA')], 'LoadCountAmounts', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, OrdinalA'), rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA')], 'ZonalStatisticsSize', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, OrdinalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, IRA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA')], 'LoadCountAmounts', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainRatioA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA')], 'LoadCountAmounts', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA')], 'JoinCountAttribute', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainIntervalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('FieldQ, PlainVectorRegionA, PlainNominalA')], 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA'), rdflib.term.Literal('ObjectQ, PointA, PlainNominalA')], 'SummarizeWithin', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA'), rdflib.term.Literal('ObjectQ, PointA, PlainOrdinalA')], 'SummarizeWithin', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA'), rdflib.term.Literal('ObjectQ, PointA, PlainIntervalA')], 'SummarizeWithin', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA'), rdflib.term.Literal('ObjectQ, PointA, ERA')], 'SummarizeWithin', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA'), rdflib.term.Literal('ObjectQ, PointA, IRA')], 'SummarizeWithin', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA'), rdflib.term.Literal('ObjectQ, PointA, PlainRatioA')], 'SummarizeWithin', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA'), rdflib.term.Literal('ObjectQ, PointA, CountA')], 'SummarizeWithin', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('FieldQ, VectorTessellationA, PlainNominalA')], 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('FieldQ, VectorTessellationA, PlainOrdinalA')], 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA')], 'ZonalStatisticsMeanInterval', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA')], 'ZonalStatisticsMeanInterval', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA')], 'ZonalStatisticsMeanInterval', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('FieldQ, PlainVectorRegionA, PlainNominalA')], 'IntersectDissolveField2Object', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA')], 'LoadCountAmounts', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), rdflib.term.Literal('FieldQ, RasterA, PlainIntervalA')], 'ZonalStatisticsMeanInterval', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsMeanInterval', rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA')], 'JoinCountAttribute', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainOrdinalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainIntervalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, IRA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainRatioA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, BooleanA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSize', rdflib.term.Literal('ObjectQ, VectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, NominalA'), rdflib.term.Literal('ObjectQ, VectorRegionA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA')], 'SpatialJoinMeanTessCount', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainOrdinalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainIntervalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, IRA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainRatioA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CountA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PointA, PlainNominalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PointA, PlainOrdinalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainNominalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PointA, PlainIntervalA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PointA, ERA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PointA, IRA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PointA, PlainRatioA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, CyclicA'), rdflib.term.Literal('ObjectQ, PointA, CountA')], 'SpatialJoinCountTess', rdflib.term.Literal('ObjectQ, VectorTessellationA, CountA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, VectorTessellationA, PlainNominalA')], 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, VectorTessellationA, PlainOrdinalA')], 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), rdflib.term.Literal('FieldQ, PlainVectorRegionA, PlainNominalA')], 'SelectLayerByLocationPlainRegionObjectsFieldDist', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, VectorTessellationA, PlainOrdinalA'), rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA')], 'SpatialJoinSumTessRatio', rdflib.term.Literal('ObjectQ, VectorTessellationA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, CyclicA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, OrdinalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, NominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))
# ([rdflib.term.Literal('ObjectQ, PlainVectorRegionA, PlainNominalA'), rdflib.term.Literal('FieldQ, RasterA, PlainRatioA')], 'ZonalStatisticsSumField', rdflib.term.Literal('ObjectQ, PlainVectorRegionA, ERA'))

# %%
# saving the multiple input triple into pickle file 
with open('triples_multiple_input.pkl', 'wb') as file:
    pickle.dump(triples_multiple, file)

# %% [markdown]
# I need to create a data frame in the same way that I did with the single input triple. However, in this case, I must first get rid of list that contains inputs in order to avoid having a list inside a list.

# %%
# opening the picke file 
with open('triples_multiple_input.pkl', 'rb') as file:
    triples_multiple = pickle.load(file)

# %%
# initializing the list 
triples_multiple_list = []

#creating a loop to go throug the triples 
for triple in triples_multiple:
    inner_list = triple[0]  # Get the list inside the triple (so the inputs)
    value = ' & '.join(str(term) for term in inner_list) #joining the inputs with "&" for indication 
    triples_multiple_list.append((value,) + triple[1:])

# %%
#converting the list into the data frame with head, relation and tail columns 
df_multiple = pd.DataFrame(triples_multiple_list, columns = ["head", "relation", "tail"])

#saving the triplets into pickle file 
with open('triples_multiple_df.pkl', 'wb') as file:
    pickle.dump(df_multiple, file)

# %% [markdown]
# ---
#
# References:
# - GeeksforGeeks. (2023). Downloading PDFs with Python using Requests and BeautifulSoup. GeeksforGeeks. https://www.geeksforgeeks.org/downloading-pdfs-with-python-using-requests-and-beautifulsoup/
